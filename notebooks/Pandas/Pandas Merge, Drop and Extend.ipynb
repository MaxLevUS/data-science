# %%
import pandas as pd
import numpy as np

# %%
forum_users = {
    'User ID': [1, 2, 3, 4, 5],
    'Username': ['maksim_l', 'jane_shith', 'bogdan_s', 'alex123', 'mark_wilson'],
    'Age': [18, 35, 25, 38, None],
    'Joined Date': pd.to_datetime(['2023-01-01', '2014-05-01','2026-11-04','2017-07-20','2018-09-11']),
    'Total Posts': [150, 230, 80, 420, 310],
    'Reputation': [500, 720, 200, 940, 500]
}

df = pd.DataFrame(forum_users)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 1        2   jane_shith  35.0  2014-05-01          230         720
# 2        3     bogdan_s  25.0  2026-11-04           80         200
# 3        4      alex123  38.0  2017-07-20          420         940
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %%
df['Language'] = 'English'
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language
# 0        1     maksim_l  18.0  2023-01-01          150         500  English
# 1        2   jane_shith  35.0  2014-05-01          230         720  English
# 2        3     bogdan_s  25.0  2026-11-04           80         200  English
# 3        4      alex123  38.0  2017-07-20          420         940  English
# 4        5  mark_wilson   NaN  2018-09-11          310         500  English

# %%
df['Reputation'] = 100
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language
# 0        1     maksim_l  18.0  2023-01-01          150         100  English
# 1        2   jane_shith  35.0  2014-05-01          230         100  English
# 2        3     bogdan_s  25.0  2026-11-04           80         100  English
# 3        4      alex123  38.0  2017-07-20          420         100  English
# 4        5  mark_wilson   NaN  2018-09-11          310         100  English

# %%
df['Reputation'] = [100, 300, 300, 200, 500]
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language
# 0        1     maksim_l  18.0  2023-01-01          150         100  English
# 1        2   jane_shith  35.0  2014-05-01          230         300  English
# 2        3     bogdan_s  25.0  2026-11-04           80         300  English
# 3        4      alex123  38.0  2017-07-20          420         200  English
# 4        5  mark_wilson   NaN  2018-09-11          310         500  English

# %%
df['Active'] = [True, False, False, True, True]
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     maksim_l  18.0  2023-01-01          150         100  English
# 1        2   jane_shith  35.0  2014-05-01          230         300  English
# 2        3     bogdan_s  25.0  2026-11-04           80         300  English
# 3        4      alex123  38.0  2017-07-20          420         200  English
# 4        5  mark_wilson   NaN  2018-09-11          310         500  English
#
#    Active
# 0    True
# 1   False
# 2   False
# 3    True
# 4    True

# %%
df['Active'] = np.array([True, False, False, True, True])
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     maksim_l  18.0  2023-01-01          150         100  English
# 1        2   jane_shith  35.0  2014-05-01          230         300  English
# 2        3     bogdan_s  25.0  2026-11-04           80         300  English
# 3        4      alex123  38.0  2017-07-20          420         200  English
# 4        5  mark_wilson   NaN  2018-09-11          310         500  English
#
#    Active
# 0    True
# 1   False
# 2   False
# 3    True
# 4    True

# %%
total_comments = {
    'Total Comments': [70, 30, 45, 55, 80]
}

df2 = pd.DataFrame(total_comments)
df2
# Out:
#    Total Comments
# 0              70
# 1              30
# 2              45
# 3              55
# 4              80

# %%
total_comments = {
    'Total Comments': [70, 30, 45, 55, 80]
}

df2 = pd.DataFrame(total_comments, index=['a', 'b', 'c', 'd', 'e'])
df2
# Out:
#    Total Comments
# a              70
# b              30
# c              45
# d              55
# e              80

# %%
total_comments = {
    'Total Comments': [70, 30, 45, 55, 80]
}

df2 = pd.DataFrame(total_comments)
df2
# Out:
#    Total Comments
# 0              70
# 1              30
# 2              45
# 3              55
# 4              80

# %%
# By default conat works on the Axis 0!
pd.concat([df, df2])
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0      1.0     maksim_l  18.0  2023-01-01        150.0       100.0  English
# 1      2.0   jane_shith  35.0  2014-05-01        230.0       300.0  English
# 2      3.0     bogdan_s  25.0  2026-11-04         80.0       300.0  English
# 3      4.0      alex123  38.0  2017-07-20        420.0       200.0  English
# 4      5.0  mark_wilson   NaN  2018-09-11        310.0       500.0  English
# 0      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 1      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 2      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 3      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 4      NaN          NaN   NaN         NaT          NaN         NaN      NaN
#
#   Active  Total Comments
# 0   True             NaN
# 1  False             NaN
# 2  False             NaN
# 3   True             NaN
# ...

# %%
pd.concat([df, df2], axis=1)
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     maksim_l  18.0  2023-01-01          150         100  English
# 1        2   jane_shith  35.0  2014-05-01          230         300  English
# 2        3     bogdan_s  25.0  2026-11-04           80         300  English
# 3        4      alex123  38.0  2017-07-20          420         200  English
# 4        5  mark_wilson   NaN  2018-09-11          310         500  English
#
#    Active  Total Comments
# 0    True              70
# 1   False              30
# 2   False              45
# 3    True              55
# 4    True              80

# %%
without_language = df.drop(['Language'], axis=1)

# %%
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     maksim_l  18.0  2023-01-01          150         100  English
# 1        2   jane_shith  35.0  2014-05-01          230         300  English
# 2        3     bogdan_s  25.0  2026-11-04           80         300  English
# 3        4      alex123  38.0  2017-07-20          420         200  English
# 4        5  mark_wilson   NaN  2018-09-11          310         500  English
#
#    Active
# 0    True
# 1   False
# 2   False
# 3    True
# 4    True

# %%
without_language
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation  Active
# 0        1     maksim_l  18.0  2023-01-01          150         100    True
# 1        2   jane_shith  35.0  2014-05-01          230         300   False
# 2        3     bogdan_s  25.0  2026-11-04           80         300   False
# 3        4      alex123  38.0  2017-07-20          420         200    True
# 4        5  mark_wilson   NaN  2018-09-11          310         500    True

# %%
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     maksim_l  18.0  2023-01-01          150         100  English
# 1        2   jane_shith  35.0  2014-05-01          230         300  English
# 2        3     bogdan_s  25.0  2026-11-04           80         300  English
# 3        4      alex123  38.0  2017-07-20          420         200  English
# 4        5  mark_wilson   NaN  2018-09-11          310         500  English
#
#    Active
# 0    True
# 1   False
# 2   False
# 3    True
# 4    True

# %%
# Original df doesn't chanched
df.drop(['Language'], axis=1)
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation  Active
# 0        1     maksim_l  18.0  2023-01-01          150         100    True
# 1        2   jane_shith  35.0  2014-05-01          230         300   False
# 2        3     bogdan_s  25.0  2026-11-04           80         300   False
# 3        4      alex123  38.0  2017-07-20          420         200    True
# 4        5  mark_wilson   NaN  2018-09-11          310         500    True

# %%
# Original df is changed inpalce
df.drop(['Language'], axis=1, inplace=True)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation  Active
# 0        1     maksim_l  18.0  2023-01-01          150         100    True
# 1        2   jane_shith  35.0  2014-05-01          230         300   False
# 2        3     bogdan_s  25.0  2026-11-04           80         300   False
# 3        4      alex123  38.0  2017-07-20          420         200    True
# 4        5  mark_wilson   NaN  2018-09-11          310         500    True

# %%
# 2 rows were deleted
df.drop([2, 3], inplace=True)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation  Active
# 0        1     maksim_l  18.0  2023-01-01          150         100    True
# 1        2   jane_shith  35.0  2014-05-01          230         300   False
# 4        5  mark_wilson   NaN  2018-09-11          310         500    True
