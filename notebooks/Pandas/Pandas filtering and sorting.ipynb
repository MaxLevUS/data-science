# %%
import pandas as pd
import numpy as np

# %%
forum_users = {
    'User ID': [1, 2, 3, 4, 5],
    'Username': ['maksim_l', 'jane_shith', 'bogdan_s', 'alex123', 'mark_wilson'],
    'Age': [18, 35, 25, 38, None],
    'Joined Date': pd.to_datetime(['2023-01-01', '2014-05-01','2026-11-04','2017-07-20','2018-09-11']),
    'Total Posts': [150, 230, 80, 420, 310],
    'Reputation': [500, 720, 200, 940, 500]
}

df = pd.DataFrame(forum_users)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 1        2   jane_shith  35.0  2014-05-01          230         720
# 2        3     bogdan_s  25.0  2026-11-04           80         200
# 3        4      alex123  38.0  2017-07-20          420         940
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %% [markdown]
# ## Filtering

# %%
df[['Username', 'Age']]
# Out:
#       Username   Age
# 0     maksim_l  18.0
# 1   jane_shith  35.0
# 2     bogdan_s  25.0
# 3      alex123  38.0
# 4  mark_wilson   NaN

# %%
df.loc[3]
# Out:
# User ID                          4
# Username                   alex123
# Age                           38.0
# Joined Date    2017-07-20 00:00:00
# Total Posts                    420
# Reputation                     940
# Name: 3, dtype: object

# %%
df.loc[2:3]
# Out:
#    User ID  Username   Age Joined Date  Total Posts  Reputation
# 2        3  bogdan_s  25.0  2026-11-04           80         200
# 3        4   alex123  38.0  2017-07-20          420         940

# %%
df.loc[2:3, ['Username', 'Joined Date', 'Reputation']]
# Out:
#    Username Joined Date  Reputation
# 2  bogdan_s  2026-11-04         200
# 3   alex123  2017-07-20         940

# %%
df.iloc[3]
# Out:
# User ID                          4
# Username                   alex123
# Age                           38.0
# Joined Date    2017-07-20 00:00:00
# Total Posts                    420
# Reputation                     940
# Name: 3, dtype: object

# %%
df.iloc[2:4]
# Out:
#    User ID  Username   Age Joined Date  Total Posts  Reputation
# 2        3  bogdan_s  25.0  2026-11-04           80         200
# 3        4   alex123  38.0  2017-07-20          420         940

# %%
df.iloc[2:4, 1:4]
# Out:
#    Username   Age Joined Date
# 2  bogdan_s  25.0  2026-11-04
# 3   alex123  38.0  2017-07-20

# %%
df.iloc[:, 1:4]
# Out:
#       Username   Age Joined Date
# 0     maksim_l  18.0  2023-01-01
# 1   jane_shith  35.0  2014-05-01
# 2     bogdan_s  25.0  2026-11-04
# 3      alex123  38.0  2017-07-20
# 4  mark_wilson   NaN  2018-09-11

# %%
df[df['Age'] >= 25]
# Out:
#    User ID    Username   Age Joined Date  Total Posts  Reputation
# 1        2  jane_shith  35.0  2014-05-01          230         720
# 2        3    bogdan_s  25.0  2026-11-04           80         200
# 3        4     alex123  38.0  2017-07-20          420         940

# %%
df['Age'] >= 25
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Age, dtype: bool

# %%
df[df['Total Posts'] >= 300]
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 3        4      alex123  38.0  2017-07-20          420         940
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %%
df[df['Reputation'] == 500]
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %%
df[(df['Total Posts']>=300) & (df['Age'] >= 25)]
# Out:
#    User ID Username   Age Joined Date  Total Posts  Reputation
# 3        4  alex123  38.0  2017-07-20          420         940

# %%
df[(df['Total Posts']>=400) | (df['Age'] <= 25)]
# Out:
#    User ID  Username   Age Joined Date  Total Posts  Reputation
# 0        1  maksim_l  18.0  2023-01-01          150         500
# 2        3  bogdan_s  25.0  2026-11-04           80         200
# 3        4   alex123  38.0  2017-07-20          420         940

# %%
df['Reputation'].isin([200, 500])
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Reputation, dtype: bool

# %%
df[df['Reputation'].isin([200, 500])]
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 2        3     bogdan_s  25.0  2026-11-04           80         200
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %%
df[df['Reputation'].isin(range(200, 500))]
# Out:
#    User ID  Username   Age Joined Date  Total Posts  Reputation
# 2        3  bogdan_s  25.0  2026-11-04           80         200

# %%
df[df['Total Posts'].isin(range(200, 350))]
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 1        2   jane_shith  35.0  2014-05-01          230         720
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %%
date_range = pd.date_range(start='2019-01-01', end='2032-08-01')
date_range
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2032-07-23', '2032-07-24', '2032-07-25', '2032-07-26',
#                '2032-07-27', '2032-07-28', '2032-07-29', '2032-07-30',
#                '2032-07-31', '2032-08-01'],
#               dtype='datetime64[ns]', length=4962, freq='D')

# %%
df[df['Joined Date'].isin(date_range)]
# Out:
#    User ID  Username   Age Joined Date  Total Posts  Reputation
# 0        1  maksim_l  18.0  2023-01-01          150         500
# 2        3  bogdan_s  25.0  2026-11-04           80         200

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by='Age')
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 2        3     bogdan_s  25.0  2026-11-04           80         200
# 1        2   jane_shith  35.0  2014-05-01          230         720
# 3        4      alex123  38.0  2017-07-20          420         940
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 3        4      alex123  38.0  2017-07-20          420         940
# 1        2   jane_shith  35.0  2014-05-01          230         720
# 2        3     bogdan_s  25.0  2026-11-04           80         200
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 4        5  mark_wilson   NaN  2018-09-11          310         500

# %%
df.sort_values(by='Joined Date')
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 1        2   jane_shith  35.0  2014-05-01          230         720
# 3        4      alex123  38.0  2017-07-20          420         940
# 4        5  mark_wilson   NaN  2018-09-11          310         500
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 2        3     bogdan_s  25.0  2026-11-04           80         200

# %%
df.sort_values(by='Joined Date', ascending=False)
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 2        3     bogdan_s  25.0  2026-11-04           80         200
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 4        5  mark_wilson   NaN  2018-09-11          310         500
# 3        4      alex123  38.0  2017-07-20          420         940
# 1        2   jane_shith  35.0  2014-05-01          230         720

# %%
df[['User ID', 'Total Posts', 'Reputation']]
# Out:
#    User ID  Total Posts  Reputation
# 0        1          150         500
# 1        2          230         720
# 2        3           80         200
# 3        4          420         940
# 4        5          310         500

# %%
# Sort by values in the row ewith index 2
df[['User ID', 'Total Posts', 'Reputation']].sort_values(by=2, axis=1, ascending=False)
# Out:
#    Reputation  Total Posts  User ID
# 0         500          150        1
# 1         720          230        2
# 2         200           80        3
# 3         940          420        4
# 4         500          310        5

# %%
df.sort_values(by='Total Posts')
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 2        3     bogdan_s  25.0  2026-11-04           80         200
# 0        1     maksim_l  18.0  2023-01-01          150         500
# 1        2   jane_shith  35.0  2014-05-01          230         720
# 4        5  mark_wilson   NaN  2018-09-11          310         500
# 3        4      alex123  38.0  2017-07-20          420         940
